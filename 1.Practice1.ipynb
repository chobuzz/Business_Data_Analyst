# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import datetime as dt

# %%
import koreanize_matplotlib

# %config InlineBackend.figure_format = 'retina'

# %%
file_path = 'data/Online Retail.xlsx'
data = pd.read_excel(file_path)

# %%
print(data.dtypes)
# Out:
# InvoiceNo              object
# StockCode              object
# Description            object
# Quantity                int64
# InvoiceDate    datetime64[ns]
# UnitPrice             float64
# CustomerID            float64
# Country                object
# dtype: object

# %%
data["InvoiceNo"] = data["InvoiceNo"].astype(str)
data["StockCode"] = data["StockCode"].astype(str)
data["Description"] = data["Description"].astype(str)
data["Country"] = data["Country"].astype(str)

# %%
parquet_path = 'data/online_retail.parquet'
data.to_parquet(parquet_path, engine='fastparquet', index=False)

# %% [markdown]
# parquet으로 불러오면 excel이나 csv보다는 훨씬 빨리 데이터를 불러올 수 있다.

# %%
df = pd.read_parquet(parquet_path)
df
# Out:
#        InvoiceNo StockCode                          Description  Quantity  \
# 0         536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1         536365     71053                  WHITE METAL LANTERN         6
# 2         536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3         536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4         536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
# ...          ...       ...                                  ...       ...
# 541904    581587     22613          PACK OF 20 SPACEBOY NAPKINS        12
# 541905    581587     22899         CHILDREN'S APRON DOLLY GIRL          6
# 541906    581587     23254        CHILDRENS CUTLERY DOLLY GIRL          4
# 541907    581587     23255      CHILDRENS CUTLERY CIRCUS PARADE         4
# 541908    581587     22138        BAKING SET 9 PIECE RETROSPOT          3
#
#                InvoiceDate  UnitPrice  CustomerID         Country
# 0      2010-12-01 08:26:00       2.55     17850.0  United Kingdom
# 1      2010-12-01 08:26:00       3.39     17850.0  United Kingdom
# 2      2010-12-01 08:26:00       2.75     17850.0  United Kingdom
# 3      2010-12-01 08:26:00       3.39     17850.0  United Kingdom
# 4      2010-12-01 08:26:00       3.39     17850.0  United Kingdom
# ...                    ...        ...         ...             ...
# 541904 2011-12-09 12:50:00       0.85     12680.0          France
# 541905 2011-12-09 12:50:00       2.10     12680.0          France
# 541906 2011-12-09 12:50:00       4.15     12680.0          France
# 541907 2011-12-09 12:50:00       4.15     12680.0          France
# 541908 2011-12-09 12:50:00       4.95     12680.0          France
#
# [541909 rows x 8 columns]

# %%
df.head()
# Out:
#   InvoiceNo StockCode                          Description  Quantity  \
# 0    536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1    536365     71053                  WHITE METAL LANTERN         6
# 2    536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4    536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
#
#           InvoiceDate  UnitPrice  CustomerID         Country
# 0 2010-12-01 08:26:00       2.55     17850.0  United Kingdom
# 1 2010-12-01 08:26:00       3.39     17850.0  United Kingdom
# 2 2010-12-01 08:26:00       2.75     17850.0  United Kingdom
# 3 2010-12-01 08:26:00       3.39     17850.0  United Kingdom
# 4 2010-12-01 08:26:00       3.39     17850.0  United Kingdom

# %%
df.tail()
# Out:
#        InvoiceNo StockCode                      Description  Quantity  \
# 541904    581587     22613      PACK OF 20 SPACEBOY NAPKINS        12
# 541905    581587     22899     CHILDREN'S APRON DOLLY GIRL          6
# 541906    581587     23254    CHILDRENS CUTLERY DOLLY GIRL          4
# 541907    581587     23255  CHILDRENS CUTLERY CIRCUS PARADE         4
# 541908    581587     22138    BAKING SET 9 PIECE RETROSPOT          3
#
#                InvoiceDate  UnitPrice  CustomerID Country
# 541904 2011-12-09 12:50:00       0.85     12680.0  France
# 541905 2011-12-09 12:50:00       2.10     12680.0  France
# 541906 2011-12-09 12:50:00       4.15     12680.0  France
# 541907 2011-12-09 12:50:00       4.15     12680.0  France
# 541908 2011-12-09 12:50:00       4.95     12680.0  France

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 541909 entries, 0 to 541908
# Data columns (total 8 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   InvoiceNo    541909 non-null  object
#  1   StockCode    541909 non-null  object
#  2   Description  541909 non-null  object
#  3   Quantity     541909 non-null  int64
#  4   InvoiceDate  541909 non-null  datetime64[ns]
#  5   UnitPrice    541909 non-null  float64
#  6   CustomerID   406829 non-null  float64
#  7   Country      541909 non-null  object
# dtypes: datetime64[ns](1), float64(2), int64(1), object(4)
# memory usage: 33.1+ MB

# %%
df["InvoiceNo"] = df["InvoiceNo"].astype("category")
df["StockCode"] = df["StockCode"].astype("category")
df["Description"] = df["Description"].astype("category")
df["InvoiceDate"] = df["InvoiceDate"].astype("category")
df["Country"] = df["Country"].astype("category")
df["Quantity"] = df["Quantity"].astype("int32")
df["UnitPrice"] = df["UnitPrice"].astype("float64")
df["CustomerID"] = df["CustomerID"].astype("float32")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 541909 entries, 0 to 541908
# Data columns (total 8 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   InvoiceNo    541909 non-null  category
#  1   StockCode    541909 non-null  category
#  2   Description  541909 non-null  category
#  3   Quantity     541909 non-null  int32
#  4   InvoiceDate  541909 non-null  category
#  5   UnitPrice    541909 non-null  float64
#  6   CustomerID   406829 non-null  float32
#  7   Country      541909 non-null  category
# dtypes: category(5), float32(1), float64(1), int32(1)
# memory usage: 15.1 MB

# %%
df.head()
# Out:
#   InvoiceNo StockCode                          Description  Quantity  \
# 0    536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1    536365     71053                  WHITE METAL LANTERN         6
# 2    536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4    536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
#
#           InvoiceDate  UnitPrice  CustomerID         Country
# 0 2010-12-01 08:26:00       2.55     17850.0  United Kingdom
# 1 2010-12-01 08:26:00       3.39     17850.0  United Kingdom
# 2 2010-12-01 08:26:00       2.75     17850.0  United Kingdom
# 3 2010-12-01 08:26:00       3.39     17850.0  United Kingdom
# 4 2010-12-01 08:26:00       3.39     17850.0  United Kingdom

# %%
df.describe()
# Out:
#             Quantity      UnitPrice     CustomerID
# count  541909.000000  541909.000000  406829.000000
# mean        9.552250       4.611114   15287.689453
# std       218.081158      96.759853    1713.600342
# min    -80995.000000  -11062.060000   12346.000000
# 25%         1.000000       1.250000   13953.000000
# 50%         3.000000       2.080000   15152.000000
# 75%        10.000000       4.130000   16791.000000
# max     80995.000000   38970.000000   18287.000000

# %% [markdown]
# describe에서 알 수 있는 정보
# - 빈도수, 평균, 표준편차, 최소값, 4분위값, 최대값

# %%
df.describe(exclude='number')
# Out:
#        InvoiceNo StockCode                         Description  \
# count     541909    541909                              541909
# unique     25900      4070                                4224
# top       573585    85123A  WHITE HANGING HEART T-LIGHT HOLDER
# freq        1114      2313                                2369
#
#                 InvoiceDate         Country
# count                541909          541909
# unique                23260              38
# top     2011-10-31 14:41:00  United Kingdom
# freq                   1114          495478

# %%
df.isnull()
# Out:
#         InvoiceNo  StockCode  Description  Quantity  InvoiceDate  UnitPrice  \
# 0           False      False        False     False        False      False
# 1           False      False        False     False        False      False
# 2           False      False        False     False        False      False
# 3           False      False        False     False        False      False
# 4           False      False        False     False        False      False
# ...           ...        ...          ...       ...          ...        ...
# 541904      False      False        False     False        False      False
# 541905      False      False        False     False        False      False
# 541906      False      False        False     False        False      False
# 541907      False      False        False     False        False      False
# 541908      False      False        False     False        False      False
#
#         CustomerID  Country
# 0            False    False
# 1            False    False
# 2            False    False
# 3            False    False
# 4            False    False
# ...            ...      ...
# 541904       False    False
# 541905       False    False
# 541906       False    False
# 541907       False    False
# 541908       False    False
#
# [541909 rows x 8 columns]

# %% [markdown]
# 결측치 보기

# %%
df.isnull().sum()
# Out:
# InvoiceNo           0
# StockCode           0
# Description         0
# Quantity            0
# InvoiceDate         0
# UnitPrice           0
# CustomerID     135080
# Country             0
# dtype: int64

# %% [markdown]
# CustomerID의 결측치는 왜 많을까? => 아마도 비회원 주문일 수 있습니다.

# %%
df.shape
# Out:
# (541909, 8)

# %% [markdown]
# * CustomerID 결측치 비율을 구해봅시다.

# %%
df.isnull().mean() * 100
# Out:
# InvoiceNo       0.000000
# StockCode       0.000000
# Description     0.000000
# Quantity        0.000000
# InvoiceDate     0.000000
# UnitPrice       0.000000
# CustomerID     24.926694
# Country         0.000000
# dtype: float64

# %% [markdown]
# * 결측치를 시각화하기

# %%
plt.figure(figsize=(12, 4))
sns.heatmap(df.isnull(), cmap='gray')
# Out:
# <Axes: >

# %% [markdown]
# ## 히스토그램으로 전체 수치변수 시각화하기

# %%
df.describe()
# Out:
#             Quantity      UnitPrice     CustomerID
# count  541909.000000  541909.000000  406829.000000
# mean        9.552250       4.611114   15287.689453
# std       218.081158      96.759853    1713.600342
# min    -80995.000000  -11062.060000   12346.000000
# 25%         1.000000       1.250000   13953.000000
# 50%         3.000000       2.080000   15152.000000
# 75%        10.000000       4.130000   16791.000000
# max     80995.000000   38970.000000   18287.000000

# %%
df.hist(figsize=(10, 6), bins=100);

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 541909 entries, 0 to 541908
# Data columns (total 8 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   InvoiceNo    541909 non-null  category
#  1   StockCode    541909 non-null  category
#  2   Description  541909 non-null  category
#  3   Quantity     541909 non-null  int32
#  4   InvoiceDate  541909 non-null  category
#  5   UnitPrice    541909 non-null  float64
#  6   CustomerID   406829 non-null  float32
#  7   Country      541909 non-null  category
# dtypes: category(5), float32(1), float64(1), int32(1)
# memory usage: 15.1 MB

# %% [markdown]
# ## 전체 주문금액 파생변수 만들기

# %%
# TotalPrice는 RFM 중 MonetaryValue의 값이 됩니다.
df['TotalPrice'] = df['Quantity'] * df['UnitPrice']
df
# Out:
#        InvoiceNo StockCode                          Description  Quantity  \
# 0         536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1         536365     71053                  WHITE METAL LANTERN         6
# 2         536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3         536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4         536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
# ...          ...       ...                                  ...       ...
# 541904    581587     22613          PACK OF 20 SPACEBOY NAPKINS        12
# 541905    581587     22899         CHILDREN'S APRON DOLLY GIRL          6
# 541906    581587     23254        CHILDRENS CUTLERY DOLLY GIRL          4
# 541907    581587     23255      CHILDRENS CUTLERY CIRCUS PARADE         4
# 541908    581587     22138        BAKING SET 9 PIECE RETROSPOT          3
#
#                InvoiceDate  UnitPrice  CustomerID         Country  TotalPrice
# 0      2010-12-01 08:26:00       2.55     17850.0  United Kingdom       15.30
# 1      2010-12-01 08:26:00       3.39     17850.0  United Kingdom       20.34
# 2      2010-12-01 08:26:00       2.75     17850.0  United Kingdom       22.00
# 3      2010-12-01 08:26:00       3.39     17850.0  United Kingdom       20.34
# 4      2010-12-01 08:26:00       3.39     17850.0  United Kingdom       20.34
# ...                    ...        ...         ...             ...         ...
# 541904 2011-12-09 12:50:00       0.85     12680.0          France       10.20
# 541905 2011-12-09 12:50:00       2.10     12680.0          France       12.60
# 541906 2011-12-09 12:50:00       4.15     12680.0          France       16.60
# 541907 2011-12-09 12:50:00       4.15     12680.0          France       16.60
# 541908 2011-12-09 12:50:00       4.95     12680.0          France       14.85
#
# [541909 rows x 9 columns]

# %%
df.hist(bins=100);

# %% [markdown]
# ## 회원 vs 비회원 구매

# %%
# isnull => 비회원, notnull => 회원
df['CustomerID'].isnull().value_counts(normalize=True)
# Out:
# CustomerID
# False    0.750733
# True     0.249267
# Name: proportion, dtype: float64

# %%
# 영국이 아닌 다른나라가 비회원을 많이 했을 가능성이 있음
# CustomerID값이 결측치가 아닌 값에 대한 Country값을 가져와 빈도수를 구합니다.
df.loc[df['CustomerID'].notnull(), 'Country'].value_counts()
# Out:
# Country
# United Kingdom          361878
# Germany                   9495
# France                    8491
# EIRE                      7485
# Spain                     2533
# Netherlands               2371
# Belgium                   2069
# Switzerland               1877
# Portugal                  1480
# Australia                 1259
# Norway                    1086
# Italy                      803
# Channel Islands            758
# Finland                    695
# Cyprus                     622
# Sweden                     462
# Austria                    401
# Denmark                    389
# Japan                      358
# Poland                     341
# USA                        291
# Israel                     250
# Unspecified                244
# Singapore                  229
# Iceland                    182
# Canada                     151
# Greece                     146
# Malta                      127
# United Arab Emirates        68
# European Community          61
# RSA                         58
# Lebanon                     45
# Lithuania                   35
# Brazil                      32
# Czech Republic              30
# Bahrain                     17
# Saudi Arabia                10
# Hong Kong                    0
# Name: count, dtype: int64

# %%
# df['isRegistered']
df['isRegistered'] = df['CustomerID'].notnull()
df
# Out:
#        InvoiceNo StockCode                          Description  Quantity  \
# 0         536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1         536365     71053                  WHITE METAL LANTERN         6
# 2         536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3         536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4         536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
# ...          ...       ...                                  ...       ...
# 541904    581587     22613          PACK OF 20 SPACEBOY NAPKINS        12
# 541905    581587     22899         CHILDREN'S APRON DOLLY GIRL          6
# 541906    581587     23254        CHILDRENS CUTLERY DOLLY GIRL          4
# 541907    581587     23255      CHILDRENS CUTLERY CIRCUS PARADE         4
# 541908    581587     22138        BAKING SET 9 PIECE RETROSPOT          3
#
#                InvoiceDate  UnitPrice  CustomerID         Country  TotalPrice  \
# 0      2010-12-01 08:26:00       2.55     17850.0  United Kingdom       15.30
# 1      2010-12-01 08:26:00       3.39     17850.0  United Kingdom       20.34
# 2      2010-12-01 08:26:00       2.75     17850.0  United Kingdom       22.00
# 3      2010-12-01 08:26:00       3.39     17850.0  United Kingdom       20.34
# 4      2010-12-01 08:26:00       3.39     17850.0  United Kingdom       20.34
# ...                    ...        ...         ...             ...         ...
# 541904 2011-12-09 12:50:00       0.85     12680.0          France       10.20
# 541905 2011-12-09 12:50:00       2.10     12680.0          France       12.60
# 541906 2011-12-09 12:50:00       4.15     12680.0          France       16.60
# 541907 2011-12-09 12:50:00       4.15     12680.0          France       16.60
# 541908 2011-12-09 12:50:00       4.95     12680.0          France       14.85
#
#         isRegistered
# 0               True
# 1               True
# 2               True
# 3               True
# 4               True
# ...              ...
# 541904          True
# 541905          True
# 541906          True
# 541907          True
# 541908          True
#
# [541909 rows x 10 columns]

# %%
pd.crosstab(df['Country'], df['isRegistered']).sort_values(True, ascending=False)
# Out:
# isRegistered           False   True
# Country
# United Kingdom        133600  361878
# Germany                    0    9495
# France                    66    8491
# EIRE                     711    7485
# Spain                      0    2533
# Netherlands                0    2371
# Belgium                    0    2069
# Switzerland              125    1877
# Portugal                  39    1480
# Australia                  0    1259
# Norway                     0    1086
# Italy                      0     803
# Channel Islands            0     758
# Finland                    0     695
# Cyprus                     0     622
# Sweden                     0     462
# Austria                    0     401
# Denmark                    0     389
# Japan                      0     358
# Poland                     0     341
# USA                        0     291
# Israel                    47     250
# Unspecified              202     244
# Singapore                  0     229
# Iceland                    0     182
# Canada                     0     151
# Greece                     0     146
# Malta                      0     127
# United Arab Emirates       0      68
# European Community         0      61
# RSA                        0      58
# Lebanon                    0      45
# Lithuania                  0      35
# Brazil                     0      32
# Czech Republic             0      30
# Bahrain                    2      17
# Saudi Arabia               0      10
# Hong Kong                288       0

# %% [markdown]
# ## 구매 취소 비율

# %%
df['InvoiceCode'] = df['InvoiceNo'].str.replace('[0-9]', '', regex=True)
df['InvoiceCode'].value_counts()
# Out:
# InvoiceCode
#      532618
# C      9288
# A         3
# Name: count, dtype: int64

# %%
df['isCancel'] = (df["InvoiceCode"] == 'C')

# %%
pd.crosstab(df["isRegistered"], df['InvoiceCode'])
# Out:
# InvoiceCode           A     C
# isRegistered
# False         134694  3   383
# True          397924  0  8905

# %%
df[df["InvoiceCode"] == 'A']
# Out:
#        InvoiceNo StockCode      Description  Quantity         InvoiceDate  \
# 299982   A563185         B  Adjust bad debt         1 2011-08-12 14:50:00
# 299983   A563186         B  Adjust bad debt         1 2011-08-12 14:51:00
# 299984   A563187         B  Adjust bad debt         1 2011-08-12 14:52:00
#
#         UnitPrice  CustomerID         Country  TotalPrice  isRegistered  \
# 299982   11062.06         NaN  United Kingdom    11062.06         False
# 299983  -11062.06         NaN  United Kingdom   -11062.06         False
# 299984  -11062.06         NaN  United Kingdom   -11062.06         False
#
#        InvoiceCode  isCancel
# 299982           A     False
# 299983           A     False
# 299984           A     False

# %%
df.shape
# Out:
# (541909, 12)

# %%
df
# Out:
#        InvoiceNo StockCode                          Description  Quantity  \
# 0         536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1         536365     71053                  WHITE METAL LANTERN         6
# 2         536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3         536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4         536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
# ...          ...       ...                                  ...       ...
# 541904    581587     22613          PACK OF 20 SPACEBOY NAPKINS        12
# 541905    581587     22899         CHILDREN'S APRON DOLLY GIRL          6
# 541906    581587     23254        CHILDRENS CUTLERY DOLLY GIRL          4
# 541907    581587     23255      CHILDRENS CUTLERY CIRCUS PARADE         4
# 541908    581587     22138        BAKING SET 9 PIECE RETROSPOT          3
#
#                InvoiceDate  UnitPrice  CustomerID         Country  TotalPrice  \
# 0      2010-12-01 08:26:00       2.55     17850.0  United Kingdom       15.30
# 1      2010-12-01 08:26:00       3.39     17850.0  United Kingdom       20.34
# 2      2010-12-01 08:26:00       2.75     17850.0  United Kingdom       22.00
# 3      2010-12-01 08:26:00       3.39     17850.0  United Kingdom       20.34
# 4      2010-12-01 08:26:00       3.39     17850.0  United Kingdom       20.34
# ...                    ...        ...         ...             ...         ...
# 541904 2011-12-09 12:50:00       0.85     12680.0          France       10.20
# 541905 2011-12-09 12:50:00       2.10     12680.0          France       12.60
# 541906 2011-12-09 12:50:00       4.15     12680.0          France       16.60
# 541907 2011-12-09 12:50:00       4.15     12680.0          France       16.60
# 541908 2011-12-09 12:50:00       4.95     12680.0          France       14.85
#
#         isRegistered InvoiceCode  isCancel
# 0               True                 False
# 1               True                 False
# 2               True                 False
# 3               True                 False
# 4               True                 False
# ...              ...         ...       ...
# 541904          True                 False
# 541905          True                 False
# 541906          True                 False
# 541907          True                 False
# 541908          True                 False
#
# [541909 rows x 12 columns]

# %%
df["CustomerID"].notnull()
# Out:
# 0         True
# 1         True
# 2         True
# 3         True
# 4         True
#           ...
# 541904    True
# 541905    True
# 541906    True
# 541907    True
# 541908    True
# Name: CustomerID, Length: 541909, dtype: bool

# %%
df[df['Quantity'] < 0]
# Out:
#        InvoiceNo StockCode                       Description  Quantity  \
# 141      C536379         D                          Discount        -1
# 154      C536383    35004C   SET OF 3 COLOURED  FLYING DUCKS        -1
# 235      C536391     22556    PLASTERS IN TIN CIRCUS PARADE        -12
# 236      C536391     21984  PACK OF 12 PINK PAISLEY TISSUES        -24
# 237      C536391     21983  PACK OF 12 BLUE PAISLEY TISSUES        -24
# ...          ...       ...                               ...       ...
# 540449   C581490     23144   ZINC T-LIGHT HOLDER STARS SMALL       -11
# 541541   C581499         M                            Manual        -1
# 541715   C581568     21258        VICTORIAN SEWING BOX LARGE        -5
# 541716   C581569     84978  HANGING HEART JAR T-LIGHT HOLDER        -1
# 541717   C581569     20979     36 PENCILS TUBE RED RETROSPOT        -5
#
#                InvoiceDate  UnitPrice  CustomerID         Country  TotalPrice  \
# 141    2010-12-01 09:41:00      27.50     14527.0  United Kingdom      -27.50
# 154    2010-12-01 09:49:00       4.65     15311.0  United Kingdom       -4.65
# 235    2010-12-01 10:24:00       1.65     17548.0  United Kingdom      -19.80
# 236    2010-12-01 10:24:00       0.29     17548.0  United Kingdom       -6.96
# 237    2010-12-01 10:24:00       0.29     17548.0  United Kingdom       -6.96
# ...                    ...        ...         ...             ...         ...
# 540449 2011-12-09 09:57:00       0.83     14397.0  United Kingdom       -9.13
# 541541 2011-12-09 10:28:00     224.69     15498.0  United Kingdom     -224.69
# 541715 2011-12-09 11:57:00      10.95     15311.0  United Kingdom      -54.75
# 541716 2011-12-09 11:58:00       1.25     17315.0  United Kingdom       -1.25
# 541717 2011-12-09 11:58:00       1.25     17315.0  United Kingdom       -6.25
#
#         isRegistered InvoiceCode  isCancel
# 141             True           C      True
# 154             True           C      True
# 235             True           C      True
# 236             True           C      True
# 237             True           C      True
# ...              ...         ...       ...
# 540449          True           C      True
# 541541          True           C      True
# 541715          True           C      True
# 541716          True           C      True
# 541717          True           C      True
#
# [10624 rows x 12 columns]

# %%
df.loc[df['Quantity'] < 0, 'InvoiceCode'].value_counts()
# Out:
# InvoiceCode
# C    9288
#      1336
# Name: count, dtype: int64

# %%
df[(df['Quantity'] < 0) & (df['InvoiceCode'] != 'C')]
# Out:
#        InvoiceNo StockCode Description  Quantity         InvoiceDate  \
# 2406      536589     21777         nan       -10 2010-12-01 16:50:00
# 4347      536764    84952C         nan       -38 2010-12-02 14:42:00
# 7188      536996     22712         nan       -20 2010-12-03 15:30:00
# 7189      536997     22028         nan       -20 2010-12-03 15:30:00
# 7190      536998     85067         nan        -6 2010-12-03 15:30:00
# ...          ...       ...         ...       ...                 ...
# 535333    581210     23395       check       -26 2011-12-07 18:36:00
# 535335    581212     22578        lost     -1050 2011-12-07 18:38:00
# 535336    581213     22576       check       -30 2011-12-07 18:38:00
# 536908    581226     23090     missing      -338 2011-12-08 09:56:00
# 538919    581422     23169     smashed      -235 2011-12-08 15:24:00
#
#         UnitPrice  CustomerID         Country  TotalPrice  isRegistered  \
# 2406          0.0         NaN  United Kingdom        -0.0         False
# 4347          0.0         NaN  United Kingdom        -0.0         False
# 7188          0.0         NaN  United Kingdom        -0.0         False
# 7189          0.0         NaN  United Kingdom        -0.0         False
# 7190          0.0         NaN  United Kingdom        -0.0         False
# ...           ...         ...             ...         ...           ...
# 535333        0.0         NaN  United Kingdom        -0.0         False
# 535335        0.0         NaN  United Kingdom        -0.0         False
# 535336        0.0         NaN  United Kingdom        -0.0         False
# 536908        0.0         NaN  United Kingdom        -0.0         False
# 538919        0.0         NaN  United Kingdom        -0.0         False
#
#        InvoiceCode  isCancel
# 2406                   False
# 4347                   False
# 7188                   False
# 7189                   False
# 7190                   False
# ...            ...       ...
# 535333                 False
# 535335                 False
# 535336                 False
# 536908                 False
# 538919                 False
#
# [1336 rows x 12 columns]

# %%
df.loc[(df['Quantity'] < 0) & (df['InvoiceCode'] != 'C'), 'Description'].value_counts()
# Out:
# Description
# nan                         862
# check                       120
# damages                      45
# damaged                      42
# ?                            41
#                            ...
# ABC TREASURE BOOK BOX         0
# A4 WALL TIDY RED FLOWERS      0
# A4 WALL TIDY BLUE OFFICE      0
# A PRETTY THANK YOU CARD       0
# website fixed                 0
# Name: count, Length: 4224, dtype: int64

# %%
df[df['Description'] == 'check']
# Out:
#        InvoiceNo StockCode Description  Quantity         InvoiceDate  \
# 13217     537425    84968F       check       -20 2010-12-06 15:35:00
# 13218     537426    84968E       check       -35 2010-12-06 15:36:00
# 108577    545546    84249A       check      -150 2011-03-03 15:03:00
# 113580    545990     84598       check     -3000 2011-03-08 13:07:00
# 381676    569875    90195A       check       -45 2011-10-06 15:07:00
# ...          ...       ...         ...       ...                 ...
# 535325    581202     23404       check        41 2011-12-07 18:30:00
# 535331    581208    72801C       check       -10 2011-12-07 18:35:00
# 535333    581210     23395       check       -26 2011-12-07 18:36:00
# 535334    581211     22142       check        14 2011-12-07 18:36:00
# 535336    581213     22576       check       -30 2011-12-07 18:38:00
#
#         UnitPrice  CustomerID         Country  TotalPrice  isRegistered  \
# 13217         0.0         NaN  United Kingdom        -0.0         False
# 13218         0.0         NaN  United Kingdom        -0.0         False
# 108577        0.0         NaN  United Kingdom        -0.0         False
# 113580        0.0         NaN  United Kingdom        -0.0         False
# 381676        0.0         NaN  United Kingdom        -0.0         False
# ...           ...         ...             ...         ...           ...
# 535325        0.0         NaN  United Kingdom         0.0         False
# 535331        0.0         NaN  United Kingdom        -0.0         False
# 535333        0.0         NaN  United Kingdom        -0.0         False
# 535334        0.0         NaN  United Kingdom         0.0         False
# 535336        0.0         NaN  United Kingdom        -0.0         False
#
#        InvoiceCode  isCancel
# 13217                  False
# 13218                  False
# 108577                 False
# 113580                 False
# 381676                 False
# ...            ...       ...
# 535325                 False
# 535331                 False
# 535333                 False
# 535334                 False
# 535336                 False
#
# [159 rows x 12 columns]

# %%
df.loc[(df['Quantity'] < 0) & (df['InvoiceCode'] != 'C'), 'Quantity'].describe()
# Out:
# count    1336.000000
# mean     -154.907934
# std       588.292456
# min     -9600.000000
# 25%       -84.000000
# 50%       -30.000000
# 75%        -8.000000
# max        -1.000000
# Name: Quantity, dtype: float64

# %%
df.loc[(df["UnitPrice"] < 0), "InvoiceCode"].value_counts()
# Out:
# InvoiceCode
# A    2
# Name: count, dtype: int64

# %%
df.loc[(df["UnitPrice"] < 0)]
# Out:
#        InvoiceNo StockCode      Description  Quantity         InvoiceDate  \
# 299983   A563186         B  Adjust bad debt         1 2011-08-12 14:51:00
# 299984   A563187         B  Adjust bad debt         1 2011-08-12 14:52:00
#
#         UnitPrice  CustomerID         Country  TotalPrice  isRegistered  \
# 299983  -11062.06         NaN  United Kingdom   -11062.06         False
# 299984  -11062.06         NaN  United Kingdom   -11062.06         False
#
#        InvoiceCode  isCancel
# 299983           A     False
# 299984           A     False

# %%
df_valid = df.loc[df['CustomerID'].notnull() & (df['Quantity'] > 0) & (df['UnitPrice'] > 0)].copy()

df.shape, df_valid.shape
# Out:
# ((541909, 12), (397884, 12))

# %%
df_valid = df_valid.drop_duplicates().copy()

df_valid.shape
# Out:
# (392692, 12)

# %% [markdown]
# ## 날짜와 시간

# %%
df_valid
# Out:
#        InvoiceNo StockCode                          Description  Quantity  \
# 0         536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1         536365     71053                  WHITE METAL LANTERN         6
# 2         536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3         536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4         536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
# ...          ...       ...                                  ...       ...
# 541904    581587     22613          PACK OF 20 SPACEBOY NAPKINS        12
# 541905    581587     22899         CHILDREN'S APRON DOLLY GIRL          6
# 541906    581587     23254        CHILDRENS CUTLERY DOLLY GIRL          4
# 541907    581587     23255      CHILDRENS CUTLERY CIRCUS PARADE         4
# 541908    581587     22138        BAKING SET 9 PIECE RETROSPOT          3
#
#                InvoiceDate  UnitPrice  CustomerID         Country  TotalPrice  \
# 0      2010-12-01 08:26:00       2.55     17850.0  United Kingdom       15.30
# 1      2010-12-01 08:26:00       3.39     17850.0  United Kingdom       20.34
# 2      2010-12-01 08:26:00       2.75     17850.0  United Kingdom       22.00
# 3      2010-12-01 08:26:00       3.39     17850.0  United Kingdom       20.34
# 4      2010-12-01 08:26:00       3.39     17850.0  United Kingdom       20.34
# ...                    ...        ...         ...             ...         ...
# 541904 2011-12-09 12:50:00       0.85     12680.0          France       10.20
# 541905 2011-12-09 12:50:00       2.10     12680.0          France       12.60
# 541906 2011-12-09 12:50:00       4.15     12680.0          France       16.60
# 541907 2011-12-09 12:50:00       4.15     12680.0          France       16.60
# 541908 2011-12-09 12:50:00       4.95     12680.0          France       14.85
#
#         isRegistered InvoiceCode  isCancel
# 0               True                 False
# 1               True                 False
# 2               True                 False
# 3               True                 False
# 4               True                 False
# ...              ...         ...       ...
# 541904          True                 False
# 541905          True                 False
# 541906          True                 False
# 541907          True                 False
# 541908          True                 False
#
# [392692 rows x 12 columns]

# %%
df_valid['InvoiceDate']
# Out:
# 0        2010-12-01 08:26:00
# 1        2010-12-01 08:26:00
# 2        2010-12-01 08:26:00
# 3        2010-12-01 08:26:00
# 4        2010-12-01 08:26:00
#                  ...
# 541904   2011-12-09 12:50:00
# 541905   2011-12-09 12:50:00
# 541906   2011-12-09 12:50:00
# 541907   2011-12-09 12:50:00
# 541908   2011-12-09 12:50:00
# Name: InvoiceDate, Length: 392692, dtype: category
# Categories (23260, datetime64[ns]): [2010-12-01 08:26:00, 2010-12-01 08:28:00, 2010-12-01 08:34:00, 2010-12-01 08:35:00, ..., 2011-12-09 12:25:00, 2011-12-09 12:31:00, 2011-12-09 12:49:00, 2011-12-09 12:50:00]

# %% [markdown]
# 비즈니스 데이터 분석 [2/7]
# 12:00

# %%
df_valid['InvoiceDate'] = pd.to_datetime(df_valid['InvoiceDate'])

# %%
df_valid['InvoiceDate']
# Out:
# 0        2010-12-01 08:26:00
# 1        2010-12-01 08:26:00
# 2        2010-12-01 08:26:00
# 3        2010-12-01 08:26:00
# 4        2010-12-01 08:26:00
#                  ...
# 541904   2011-12-09 12:50:00
# 541905   2011-12-09 12:50:00
# 541906   2011-12-09 12:50:00
# 541907   2011-12-09 12:50:00
# 541908   2011-12-09 12:50:00
# Name: InvoiceDate, Length: 392692, dtype: datetime64[ns]

# %%
df_valid['InvoiceYear'] = df_valid['InvoiceDate'].dt.year
df_valid["InvoiceMonth"] = df_valid["InvoiceDate"].dt.month
df_valid["InvoiceDay"] = df_valid["InvoiceDate"].dt.day
df_valid["InvoiceDow"] = df_valid["InvoiceDate"].dt.dayofweek

# %%
df_valid.head()
# Out:
#   InvoiceNo StockCode                          Description  Quantity  \
# 0    536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1    536365     71053                  WHITE METAL LANTERN         6
# 2    536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4    536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
#
#           InvoiceDate  UnitPrice  CustomerID         Country  TotalPrice  \
# 0 2010-12-01 08:26:00       2.55     17850.0  United Kingdom       15.30
# 1 2010-12-01 08:26:00       3.39     17850.0  United Kingdom       20.34
# 2 2010-12-01 08:26:00       2.75     17850.0  United Kingdom       22.00
# 3 2010-12-01 08:26:00       3.39     17850.0  United Kingdom       20.34
# 4 2010-12-01 08:26:00       3.39     17850.0  United Kingdom       20.34
#
#    isRegistered InvoiceCode  isCancel  InvoiceYear  InvoiceMonth  InvoiceDay  \
# 0          True                 False         2010            12           1
# 1          True                 False         2010            12           1
# 2          True                 False         2010            12           1
# 3          True                 False         2010            12           1
# 4          True                 False         2010            12           1
#
#    InvoiceDow
# 0           2
# 1           2
# 2           2
# 3           2
# 4           2

# %%
df_valid['InvoiceYM'] = df['InvoiceDate'].astype(str).str[:7]
df_valid[['InvoiceDate', 'InvoiceYM']].sample(2)
# Out:
#                InvoiceDate InvoiceYM
# 450103 2011-11-08 16:55:00   2011-11
# 421023 2011-10-26 16:21:00   2011-10

# %%
df_valid['InvoiceTime'] = df_valid['InvoiceDate'].dt.time
df_valid["InvoiceHour"] = df_valid["InvoiceDate"].dt.hour
df_valid.head(2)
# Out:
#   InvoiceNo StockCode                         Description  Quantity  \
# 0    536365    85123A  WHITE HANGING HEART T-LIGHT HOLDER         6
# 1    536365     71053                 WHITE METAL LANTERN         6
#
#           InvoiceDate  UnitPrice  CustomerID         Country  TotalPrice  \
# 0 2010-12-01 08:26:00       2.55     17850.0  United Kingdom       15.30
# 1 2010-12-01 08:26:00       3.39     17850.0  United Kingdom       20.34
#
#    isRegistered InvoiceCode  isCancel  InvoiceYear  InvoiceMonth  InvoiceDay  \
# 0          True                 False         2010            12           1
# 1          True                 False         2010            12           1
#
#    InvoiceDow InvoiceYM InvoiceTime  InvoiceHour
# 0           2   2010-12    08:26:00            8
# 1           2   2010-12    08:26:00            8

# %%
df_valid.hist(figsize=(15,12), bins=50);

# %% [markdown]
# ### 연도별 구매 빈도수 시각화

# %%
sns.countplot(data=df_valid, x='InvoiceYear')
# Out:
# <Axes: xlabel='InvoiceYear', ylabel='count'>

# %%
sns.countplot(data=df_valid, x="InvoiceMonth", hue="InvoiceYear")
# Out:
# <Axes: xlabel='InvoiceMonth', ylabel='count'>

# %%
sns.countplot(data=df_valid, x="InvoiceMonth")
# Out:
# <Axes: xlabel='InvoiceMonth', ylabel='count'>

# %%
plt.figure(figsize=(12,4))
sns.countplot(data=df_valid, x='InvoiceYM', palette='pastel')
# Out:
# C:\Users\chobu\AppData\Local\Temp\ipykernel_16072\1104148702.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(data=df_valid, x='InvoiceYM', palette='pastel')
# <Axes: xlabel='InvoiceYM', ylabel='count'>

# %%
df_valid[df_valid['InvoiceYM'] == '2011-12'].shape
# Out:
# (17026, 19)

# %%
sns.countplot(data=df_valid, x="InvoiceDow", palette="muted")
# Out:
# C:\Users\chobu\AppData\Local\Temp\ipykernel_16072\4158791863.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(data=df_valid, x="InvoiceDow", palette="muted")
# <Axes: xlabel='InvoiceDow', ylabel='count'>

# %%
df_valid['InvoiceDow'].value_counts().sort_index()
# Out:
# InvoiceDow
# 0    64231
# 1    65744
# 2    68040
# 3    79243
# 4    54222
# 6    61212
# Name: count, dtype: int64

# %%
day_name = ['월', '화', '수', '목', '금', '토', '일']
day_name
# Out:
# ['월', '화', '수', '목', '금', '토', '일']

# %%
day_name.remove('토')
day_name
# Out:
# ['월', '화', '수', '목', '금', '일']

# %%
dow_count = df_valid["InvoiceDow"].value_counts().sort_index()
dow_count.index = day_name
dow_count
# Out:
# 월    64231
# 화    65744
# 수    68040
# 목    79243
# 금    54222
# 일    61212
# Name: count, dtype: int64

# %%
dow_count.plot.bar(figsize=(12,3), rot=0)
# Out:
# <Axes: >

# %%
df_valid["InvoiceDayName"] = df_valid["InvoiceDow"].map(lambda x: "월화수목금토일"[x])

# %%
sns.countplot(data=df_valid, x='InvoiceDayName', order=list('월화수목금토일'), palette='muted')
# Out:
# C:\Users\chobu\AppData\Local\Temp\ipykernel_16072\3172297923.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(data=df_valid, x='InvoiceDayName', order=list('월화수목금토일'), palette='muted')
# <Axes: xlabel='InvoiceDayName', ylabel='count'>

# %% [markdown]
# 28:07

# %%
plt.figure(figsize=(12,4))
sns.countplot(data=df_valid, x='InvoiceHour')
# Out:
# <Axes: xlabel='InvoiceHour', ylabel='count'>

# %%
plt.figure(figsize=(12,4))
sns.pointplot(data=df_valid, x='InvoiceHour', y='TotalPrice', estimator=len, errorbar=None).set_title('시간대별 주문량')
# Out:
# Text(0.5, 1.0, '시간대별 주문량')

# %%
plt.figure(figsize=(12, 4))
sns.pointplot(
    data=df_valid, x="InvoiceHour", y="TotalPrice", estimator='sum', errorbar=None).set_title('시간대별 매출액')
# Out:
# Text(0.5, 1.0, '시간대별 매출액')

# %%
list('월화수목금일')
hour_dow = pd.crosstab(df_valid["InvoiceHour"], df_valid["InvoiceDayName"])[
    list("월화수목금일")
]
hour_dow
# Out:
# InvoiceDayName      월      화      수      목     금      일
# InvoiceHour
# 6                   0      0      0      1     0      0
# 7                  61     65     59     64   130      0
# 8                1563   1710   1818   1763  1833      0
# 9                4345   4542   4078   4569  4368     25
# 10               6106   6575   6927   7528  7161   3476
# 11               7401   8418   8292   7134  7189   9931
# 12              10585  11903  12684  12908  9765  13093
# 13              10459  10274  11137  11446  8300  11403
# 14               9119   9428   8716   9173  7227   9588
# 15               7634   7219   7752   7616  4682   9887
# 16               3999   3592   4197   6031  2087   3809
# 17               2959   1951   2348   4300  1383      0
# 18                  0     67      0   2826     2      0
# 19                  0      0     14   3131    88      0
# 20                  0      0     18    753     7      0

# %%
hour_dow.style.background_gradient(axis=None)
# Out:
# <style type="text/css">
# #T_2e96c_row0_col0, #T_2e96c_row0_col1, #T_2e96c_row0_col2, #T_2e96c_row0_col3, #T_2e96c_row0_col4, #T_2e96c_row0_col5, #T_2e96c_row1_col5, #T_2e96c_row2_col5, #T_2e96c_row3_col5, #T_2e96c_row11_col5, #T_2e96c_row12_col0, #T_2e96c_row12_col2, #T_2e96c_row12_col4, #T_2e96c_row12_col5, #T_2e96c_row13_col0, #T_2e96c_row13_col1, #T_2e96c_row13_col2, #T_2e96c_row13_col5, #T_2e96c_row14_col0, #T_2e96c_row14_col1, #T_2e96c_row14_col2, #T_2e96c_row14_col4, #T_2e96c_row14_col5 {
#   background-color: #fff7fb;
#   color: #000000;
# }
# #T_2e96c_row1_col0, #T_2e96c_row1_col1, #T_2e96c_row1_col2, #T_2e96c_row1_col3, #T_2e96c_row12_col1, #T_2e96c_row13_col4 {
#   background-color: #fef6fb;
#   color: #000000;
# }
# #T_2e96c_row1_col4 {
#   background-color: #fef6fa;
#   color: #000000;
# }
# #T_2e96c_row2_col0 {
#   background-color: #ede8f3;
#   color: #000000;
# }
# #T_2e96c_row2_col1 {
#   background-color: #ebe6f2;
#   color: #000000;
# }
# #T_2e96c_row2_col2, #T_2e96c_row2_col4 {
#   background-color: #e9e5f1;
#   color: #000000;
# }
# #T_2e96c_row2_col3 {
#   background-color: #eae6f1;
#   color: #000000;
# }
# #T_2e96c_row3_col0, #T_2e96c_row11_col3 {
#   background-color: #b5c4df;
#   color: #000000;
# }
# #T_2e96c_row3_col1 {
#   background-color: #b0c2de;
#   color: #000000;
# }
# #T_2e96c_row3_col2 {
#   background-color: #bcc7e1;
#   color: #000000;
# }
# #T_2e96c_row3_col3 {
#   background-color: #afc1dd;
#   color: #000000;
# }
# #T_2e96c_row3_col4 {
#   background-color: #b4c4df;
#   color: #000000;
# }
# #T_2e96c_row4_col0 {
#   background-color: #81aed2;
#   color: #f1f1f1;
# }
# #T_2e96c_row4_col1 {
#   background-color: #73a9cf;
#   color: #f1f1f1;
# }
# #T_2e96c_row4_col2 {
#   background-color: #65a3cb;
#   color: #f1f1f1;
# }
# #T_2e96c_row4_col3 {
#   background-color: #4e9ac6;
#   color: #f1f1f1;
# }
# #T_2e96c_row4_col4, #T_2e96c_row5_col4 {
#   background-color: #5c9fc9;
#   color: #f1f1f1;
# }
# #T_2e96c_row4_col5 {
#   background-color: #cccfe5;
#   color: #000000;
# }
# #T_2e96c_row5_col0 {
#   background-color: #549cc7;
#   color: #f1f1f1;
# }
# #T_2e96c_row5_col1 {
#   background-color: #2f8bbe;
#   color: #f1f1f1;
# }
# #T_2e96c_row5_col2, #T_2e96c_row7_col4 {
#   background-color: #328dbf;
#   color: #f1f1f1;
# }
# #T_2e96c_row5_col3 {
#   background-color: #5ea0ca;
#   color: #f1f1f1;
# }
# #T_2e96c_row5_col5 {
#   background-color: #056ead;
#   color: #f1f1f1;
# }
# #T_2e96c_row6_col0 {
#   background-color: #0566a0;
#   color: #f1f1f1;
# }
# #T_2e96c_row6_col1 {
#   background-color: #03517e;
#   color: #f1f1f1;
# }
# #T_2e96c_row6_col2 {
#   background-color: #023f64;
#   color: #f1f1f1;
# }
# #T_2e96c_row6_col3 {
#   background-color: #023b5d;
#   color: #f1f1f1;
# }
# #T_2e96c_row6_col4 {
#   background-color: #0771b1;
#   color: #f1f1f1;
# }
# #T_2e96c_row6_col5 {
#   background-color: #023858;
#   color: #f1f1f1;
# }
# #T_2e96c_row7_col0 {
#   background-color: #0567a2;
#   color: #f1f1f1;
# }
# #T_2e96c_row7_col1 {
#   background-color: #056aa6;
#   color: #f1f1f1;
# }
# #T_2e96c_row7_col2 {
#   background-color: #045e94;
#   color: #f1f1f1;
# }
# #T_2e96c_row7_col3 {
#   background-color: #045a8d;
#   color: #f1f1f1;
# }
# #T_2e96c_row7_col5 {
#   background-color: #045b8e;
#   color: #f1f1f1;
# }
# #T_2e96c_row8_col0 {
#   background-color: #197db7;
#   color: #f1f1f1;
# }
# #T_2e96c_row8_col1 {
#   background-color: #1077b4;
#   color: #f1f1f1;
# }
# #T_2e96c_row8_col2 {
#   background-color: #2685bb;
#   color: #f1f1f1;
# }
# #T_2e96c_row8_col3 {
#   background-color: #187cb6;
#   color: #f1f1f1;
# }
# #T_2e96c_row8_col4, #T_2e96c_row9_col1 {
#   background-color: #5a9ec9;
#   color: #f1f1f1;
# }
# #T_2e96c_row8_col5 {
#   background-color: #0c74b2;
#   color: #f1f1f1;
# }
# #T_2e96c_row9_col0 {
#   background-color: #4a98c5;
#   color: #f1f1f1;
# }
# #T_2e96c_row9_col2 {
#   background-color: #4697c4;
#   color: #f1f1f1;
# }
# #T_2e96c_row9_col3 {
#   background-color: #4c99c5;
#   color: #f1f1f1;
# }
# #T_2e96c_row9_col4 {
#   background-color: #acc0dd;
#   color: #000000;
# }
# #T_2e96c_row9_col5 {
#   background-color: #056fae;
#   color: #f1f1f1;
# }
# #T_2e96c_row10_col0 {
#   background-color: #bdc8e1;
#   color: #000000;
# }
# #T_2e96c_row10_col1 {
#   background-color: #c8cde4;
#   color: #000000;
# }
# #T_2e96c_row10_col2 {
#   background-color: #b8c6e0;
#   color: #000000;
# }
# #T_2e96c_row10_col3 {
#   background-color: #84b0d3;
#   color: #f1f1f1;
# }
# #T_2e96c_row10_col4 {
#   background-color: #e5e1ef;
#   color: #000000;
# }
# #T_2e96c_row10_col5 {
#   background-color: #c2cbe2;
#   color: #000000;
# }
# #T_2e96c_row11_col0 {
#   background-color: #d6d6e9;
#   color: #000000;
# }
# #T_2e96c_row11_col1 {
#   background-color: #e7e3f0;
#   color: #000000;
# }
# #T_2e96c_row11_col2 {
#   background-color: #e0deed;
#   color: #000000;
# }
# #T_2e96c_row11_col4 {
#   background-color: #efe9f3;
#   color: #000000;
# }
# #T_2e96c_row12_col3 {
#   background-color: #d8d7e9;
#   color: #000000;
# }
# #T_2e96c_row13_col3 {
#   background-color: #d2d3e7;
#   color: #000000;
# }
# #T_2e96c_row14_col3 {
#   background-color: #f7f0f7;
#   color: #000000;
# }
# </style>
# <table id="T_2e96c">
#   <thead>
#     <tr>
#       <th class="index_name level0" >InvoiceDayName</th>
#       <th id="T_2e96c_level0_col0" class="col_heading level0 col0" >월</th>
#       <th id="T_2e96c_level0_col1" class="col_heading level0 col1" >화</th>
#       <th id="T_2e96c_level0_col2" class="col_heading level0 col2" >수</th>
#       <th id="T_2e96c_level0_col3" class="col_heading level0 col3" >목</th>
#       <th id="T_2e96c_level0_col4" class="col_heading level0 col4" >금</th>
#       <th id="T_2e96c_level0_col5" class="col_heading level0 col5" >일</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >InvoiceHour</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_2e96c_level0_row0" class="row_heading level0 row0" >6</th>
#       <td id="T_2e96c_row0_col0" class="data row0 col0" >0</td>
#       <td id="T_2e96c_row0_col1" class="data row0 col1" >0</td>
#       <td id="T_2e96c_row0_col2" class="data row0 col2" >0</td>
#       <td id="T_2e96c_row0_col3" class="data row0 col3" >1</td>
#       <td id="T_2e96c_row0_col4" class="data row0 col4" >0</td>
#       <td id="T_2e96c_row0_col5" class="data row0 col5" >0</td>
#     </tr>
#     <tr>
#       <th id="T_2e96c_level0_row1" class="row_heading level0 row1" >7</th>
#       <td id="T_2e96c_row1_col0" class="data row1 col0" >61</td>
#       <td id="T_2e96c_row1_col1" class="data row1 col1" >65</td>
#       <td id="T_2e96c_row1_col2" class="data row1 col2" >59</td>
#       <td id="T_2e96c_row1_col3" class="data row1 col3" >64</td>
#       <td id="T_2e96c_row1_col4" class="data row1 col4" >130</td>
#       <td id="T_2e96c_row1_col5" class="data row1 col5" >0</td>
#     </tr>
#     <tr>
#       <th id="T_2e96c_level0_row2" class="row_heading level0 row2" >8</th>
#       <td id="T_2e96c_row2_col0" class="data row2 col0" >1563</td>
#       <td id="T_2e96c_row2_col1" class="data row2 col1" >1710</td>
#       <td id="T_2e96c_row2_col2" class="data row2 col2" >1818</td>
#       <td id="T_2e96c_row2_col3" class="data row2 col3" >1763</td>
#       <td id="T_2e96c_row2_col4" class="data row2 col4" >1833</td>
#       <td id="T_2e96c_row2_col5" class="data row2 col5" >0</td>
#     </tr>
#     <tr>
#       <th id="T_2e96c_level0_row3" class="row_heading level0 row3" >9</th>
#       <td id="T_2e96c_row3_col0" class="data row3 col0" >4345</td>
#       <td id="T_2e96c_row3_col1" class="data row3 col1" >4542</td>
#       <td id="T_2e96c_row3_col2" class="data row3 col2" >4078</td>
#       <td id="T_2e96c_row3_col3" class="data row3 col3" >4569</td>
#       <td id="T_2e96c_row3_col4" class="data row3 col4" >4368</td>
#       <td id="T_2e96c_row3_col5" class="data row3 col5" >25</td>
#     </tr>
#     <tr>
#       <th id="T_2e96c_level0_row4" class="row_heading level0 row4" >10</th>
#       <td id="T_2e96c_row4_col0" class="data row4 col0" >6106</td>
#       <td id="T_2e96c_row4_col1" class="data row4 col1" >6575</td>
#       <td id="T_2e96c_row4_col2" class="data row4 col2" >6927</td>
#       <td id="T_2e96c_row4_col3" class="data row4 col3" >7528</td>
#       <td id="T_2e96c_row4_col4"

# %%
print(plt.colormaps)
# Out:
# ColormapRegistry; available colormaps:
# 'magma', 'inferno', 'plasma', 'viridis', 'cividis', 'twilight', 'twilight_shifted', 'turbo', 'berlin', 'managua', 'vanimo', 'Blues', 'BrBG', 'BuGn', 'BuPu', 'CMRmap', 'GnBu', 'Greens', 'Greys', 'OrRd', 'Oranges', 'PRGn', 'PiYG', 'PuBu', 'PuBuGn', 'PuOr', 'PuRd', 'Purples', 'RdBu', 'RdGy', 'RdPu', 'RdYlBu', 'RdYlGn', 'Reds', 'Spectral', 'Wistia', 'YlGn', 'YlGnBu', 'YlOrBr', 'YlOrRd', 'afmhot', 'autumn', 'binary', 'bone', 'brg', 'bwr', 'cool', 'coolwarm', 'copper', 'cubehelix', 'flag', 'gist_earth', 'gist_gray', 'gist_heat', 'gist_ncar', 'gist_rainbow', 'gist_stern', 'gist_yarg', 'gnuplot', 'gnuplot2', 'gray', 'hot', 'hsv', 'jet', 'nipy_spectral', 'ocean', 'pink', 'prism', 'rainbow', 'seismic', 'spring', 'summer', 'terrain', 'winter', 'Accent', 'Dark2', 'Paired', 'Pastel1', 'Pastel2', 'Set1', 'Set2', 'Set3', 'tab10', 'tab20', 'tab20b', 'tab20c', 'grey', 'gist_grey', 'gist_yerg', 'Grays', 'magma_r', 'inferno_r', 'plasma_r', 'viridis_r', 'cividis_r', 'twilight_r', 'twilight_shifted_r', 'turbo_r', 'berlin_r', 'managua_r', 'vanimo_r', 'Blues_r', 'BrBG_r', 'BuGn_r', 'BuPu_r', 'CMRmap_r', 'GnBu_r', 'Greens_r', 'Greys_r', 'OrRd_r', 'Oranges_r', 'PRGn_r', 'PiYG_r', 'PuBu_r', 'PuBuGn_r', 'PuOr_r', 'PuRd_r', 'Purples_r', 'RdBu_r', 'RdGy_r', 'RdPu_r', 'RdYlBu_r', 'RdYlGn_r', 'Reds_r', 'Spectral_r', 'Wistia_r', 'YlGn_r', 'YlGnBu_r', 'YlOrBr_r', 'YlOrRd_r', 'afmhot_r', 'autumn_r', 'binary_r', 'bone_r', 'brg_r', 'bwr_r', 'cool_r', 'coolwarm_r', 'copper_r', 'cubehelix_r', 'flag_r', 'gist_earth_r', 'gist_gray_r', 'gist_heat_r', 'gist_ncar_r', 'gist_rainbow_r', 'gist_stern_r', 'gist_yarg_r', 'gnuplot_r', 'gnuplot2_r', 'gray_r', 'hot_r', 'hsv_r', 'jet_r', 'nipy_spectral_r', 'ocean_r', 'pink_r', 'prism_r', 'rainbow_r', 'seismic_r', 'spring_r', 'summer_r', 'terrain_r', 'winter_r', 'Accent_r', 'Dark2_r', 'Paired_r', 'Pastel1_r', 'Pastel2_r', 'Set1_r', 'Set2_r', 'Set3_r', 'tab10_r', 'tab20_r', 'tab20b_r', 'tab20c_r', 'grey_r', 'gist_grey_r', 'gist_yerg_r', 'Grays_r', 'rocket', 'rocket_r', 'mako', 'mako_r', 'icefire', 'icefire_r', 'vlag', 'vlag_r', 'flare', 'flare_r', 'crest', 'crest_r'

# %%
hour_dow.style.background_gradient(axis=None, cmap="Blues").format('{:,}')
# Out:
# <style type="text/css">
# #T_8ac86_row0_col0, #T_8ac86_row0_col1, #T_8ac86_row0_col2, #T_8ac86_row0_col3, #T_8ac86_row0_col4, #T_8ac86_row0_col5, #T_8ac86_row1_col5, #T_8ac86_row2_col5, #T_8ac86_row3_col5, #T_8ac86_row11_col5, #T_8ac86_row12_col0, #T_8ac86_row12_col2, #T_8ac86_row12_col4, #T_8ac86_row12_col5, #T_8ac86_row13_col0, #T_8ac86_row13_col1, #T_8ac86_row13_col2, #T_8ac86_row13_col5, #T_8ac86_row14_col0, #T_8ac86_row14_col1, #T_8ac86_row14_col2, #T_8ac86_row14_col4, #T_8ac86_row14_col5 {
#   background-color: #f7fbff;
#   color: #000000;
# }
# #T_8ac86_row1_col0, #T_8ac86_row1_col1, #T_8ac86_row1_col2, #T_8ac86_row1_col3, #T_8ac86_row12_col1, #T_8ac86_row13_col4 {
#   background-color: #f6faff;
#   color: #000000;
# }
# #T_8ac86_row1_col4 {
#   background-color: #f5fafe;
#   color: #000000;
# }
# #T_8ac86_row2_col0 {
#   background-color: #dfecf7;
#   color: #000000;
# }
# #T_8ac86_row2_col1 {
#   background-color: #ddeaf7;
#   color: #000000;
# }
# #T_8ac86_row2_col2, #T_8ac86_row2_col4 {
#   background-color: #dce9f6;
#   color: #000000;
# }
# #T_8ac86_row2_col3 {
#   background-color: #dceaf6;
#   color: #000000;
# }
# #T_8ac86_row3_col0, #T_8ac86_row11_col3 {
#   background-color: #add0e6;
#   color: #000000;
# }
# #T_8ac86_row3_col1 {
#   background-color: #a8cee4;
#   color: #000000;
# }
# #T_8ac86_row3_col2 {
#   background-color: #b3d3e8;
#   color: #000000;
# }
# #T_8ac86_row3_col3 {
#   background-color: #a6cee4;
#   color: #000000;
# }
# #T_8ac86_row3_col4 {
#   background-color: #abd0e6;
#   color: #000000;
# }
# #T_8ac86_row4_col0 {
#   background-color: #79b5d9;
#   color: #000000;
# }
# #T_8ac86_row4_col1 {
#   background-color: #6aaed6;
#   color: #f1f1f1;
# }
# #T_8ac86_row4_col2 {
#   background-color: #61a7d2;
#   color: #f1f1f1;
# }
# #T_8ac86_row4_col3 {
#   background-color: #529dcc;
#   color: #f1f1f1;
# }
# #T_8ac86_row4_col4, #T_8ac86_row5_col4 {
#   background-color: #5ba3d0;
#   color: #f1f1f1;
# }
# #T_8ac86_row4_col5 {
#   background-color: #c2d9ee;
#   color: #000000;
# }
# #T_8ac86_row5_col0 {
#   background-color: #56a0ce;
#   color: #f1f1f1;
# }
# #T_8ac86_row5_col1 {
#   background-color: #3d8dc4;
#   color: #f1f1f1;
# }
# #T_8ac86_row5_col2, #T_8ac86_row7_col4 {
#   background-color: #3f8fc5;
#   color: #f1f1f1;
# }
# #T_8ac86_row5_col3 {
#   background-color: #5ca4d0;
#   color: #f1f1f1;
# }
# #T_8ac86_row5_col5 {
#   background-color: #1f6eb3;
#   color: #f1f1f1;
# }
# #T_8ac86_row6_col0 {
#   background-color: #1562a9;
#   color: #f1f1f1;
# }
# #T_8ac86_row6_col1 {
#   background-color: #08488e;
#   color: #f1f1f1;
# }
# #T_8ac86_row6_col2 {
#   background-color: #083776;
#   color: #f1f1f1;
# }
# #T_8ac86_row6_col3 {
#   background-color: #083370;
#   color: #f1f1f1;
# }
# #T_8ac86_row6_col4 {
#   background-color: #2272b6;
#   color: #f1f1f1;
# }
# #T_8ac86_row6_col5 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# #T_8ac86_row7_col0 {
#   background-color: #1764ab;
#   color: #f1f1f1;
# }
# #T_8ac86_row7_col1 {
#   background-color: #1a68ae;
#   color: #f1f1f1;
# }
# #T_8ac86_row7_col2 {
#   background-color: #0d57a1;
#   color: #f1f1f1;
# }
# #T_8ac86_row7_col3 {
#   background-color: #08519c;
#   color: #f1f1f1;
# }
# #T_8ac86_row7_col5 {
#   background-color: #09529d;
#   color: #f1f1f1;
# }
# #T_8ac86_row8_col0 {
#   background-color: #2f7fbc;
#   color: #f1f1f1;
# }
# #T_8ac86_row8_col1 {
#   background-color: #2979b9;
#   color: #f1f1f1;
# }
# #T_8ac86_row8_col2 {
#   background-color: #3787c0;
#   color: #f1f1f1;
# }
# #T_8ac86_row8_col3 {
#   background-color: #2e7ebc;
#   color: #f1f1f1;
# }
# #T_8ac86_row8_col4, #T_8ac86_row9_col1 {
#   background-color: #5aa2cf;
#   color: #f1f1f1;
# }
# #T_8ac86_row8_col5 {
#   background-color: #2575b7;
#   color: #f1f1f1;
# }
# #T_8ac86_row9_col0 {
#   background-color: #4f9bcb;
#   color: #f1f1f1;
# }
# #T_8ac86_row9_col2 {
#   background-color: #4d99ca;
#   color: #f1f1f1;
# }
# #T_8ac86_row9_col3 {
#   background-color: #519ccc;
#   color: #f1f1f1;
# }
# #T_8ac86_row9_col4 {
#   background-color: #a4cce3;
#   color: #000000;
# }
# #T_8ac86_row9_col5 {
#   background-color: #206fb4;
#   color: #f1f1f1;
# }
# #T_8ac86_row10_col0 {
#   background-color: #b4d3e9;
#   color: #000000;
# }
# #T_8ac86_row10_col1 {
#   background-color: #bed8ec;
#   color: #000000;
# }
# #T_8ac86_row10_col2 {
#   background-color: #afd1e7;
#   color: #000000;
# }
# #T_8ac86_row10_col3 {
#   background-color: #7cb7da;
#   color: #000000;
# }
# #T_8ac86_row10_col4 {
#   background-color: #d8e7f5;
#   color: #000000;
# }
# #T_8ac86_row10_col5 {
#   background-color: #b9d6ea;
#   color: #000000;
# }
# #T_8ac86_row11_col0 {
#   background-color: #cbdef1;
#   color: #000000;
# }
# #T_8ac86_row11_col1 {
#   background-color: #d9e8f5;
#   color: #000000;
# }
# #T_8ac86_row11_col2 {
#   background-color: #d4e4f4;
#   color: #000000;
# }
# #T_8ac86_row11_col4 {
#   background-color: #e2edf8;
#   color: #000000;
# }
# #T_8ac86_row12_col3 {
#   background-color: #cddff1;
#   color: #000000;
# }
# #T_8ac86_row13_col3 {
#   background-color: #c8dcf0;
#   color: #000000;
# }
# #T_8ac86_row14_col3 {
#   background-color: #ecf4fb;
#   color: #000000;
# }
# </style>
# <table id="T_8ac86">
#   <thead>
#     <tr>
#       <th class="index_name level0" >InvoiceDayName</th>
#       <th id="T_8ac86_level0_col0" class="col_heading level0 col0" >월</th>
#       <th id="T_8ac86_level0_col1" class="col_heading level0 col1" >화</th>
#       <th id="T_8ac86_level0_col2" class="col_heading level0 col2" >수</th>
#       <th id="T_8ac86_level0_col3" class="col_heading level0 col3" >목</th>
#       <th id="T_8ac86_level0_col4" class="col_heading level0 col4" >금</th>
#       <th id="T_8ac86_level0_col5" class="col_heading level0 col5" >일</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >InvoiceHour</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_8ac86_level0_row0" class="row_heading level0 row0" >6</th>
#       <td id="T_8ac86_row0_col0" class="data row0 col0" >0</td>
#       <td id="T_8ac86_row0_col1" class="data row0 col1" >0</td>
#       <td id="T_8ac86_row0_col2" class="data row0 col2" >0</td>
#       <td id="T_8ac86_row0_col3" class="data row0 col3" >1</td>
#       <td id="T_8ac86_row0_col4" class="data row0 col4" >0</td>
#       <td id="T_8ac86_row0_col5" class="data row0 col5" >0</td>
#     </tr>
#     <tr>
#       <th id="T_8ac86_level0_row1" class="row_heading level0 row1" >7</th>
#       <td id="T_8ac86_row1_col0" class="data row1 col0" >61</td>
#       <td id="T_8ac86_row1_col1" class="data row1 col1" >65</td>
#       <td id="T_8ac86_row1_col2" class="data row1 col2" >59</td>
#       <td id="T_8ac86_row1_col3" class="data row1 col3" >64</td>
#       <td id="T_8ac86_row1_col4" class="data row1 col4" >130</td>
#       <td id="T_8ac86_row1_col5" class="data row1 col5" >0</td>
#     </tr>
#     <tr>
#       <th id="T_8ac86_level0_row2" class="row_heading level0 row2" >8</th>
#       <td id="T_8ac86_row2_col0" class="data row2 col0" >1,563</td>
#       <td id="T_8ac86_row2_col1" class="data row2 col1" >1,710</td>
#       <td id="T_8ac86_row2_col2" class="data row2 col2" >1,818</td>
#       <td id="T_8ac86_row2_col3" class="data row2 col3" >1,763</td>
#       <td id="T_8ac86_row2_col4" class="data row2 col4" >1,833</td>
#       <td id="T_8ac86_row2_col5" class="data row2 col5" >0</td>
#     </tr>
#     <tr>
#       <th id="T_8ac86_level0_row3" class="row_heading level0 row3" >9</th>
#       <td id="T_8ac86_row3_col0" class="data row3 col0" >4,345</td>
#       <td id="T_8ac86_row3_col1" class="data row3 col1" >4,542</td>
#       <td id="T_8ac86_row3_col2" class="data row3 col2" >4,078</td>
#       <td id="T_8ac86_row3_col3" class="data row3 col3" >4,569</td>
#       <td id="T_8ac86_row3_col4" class="data row3 col4" >4,368</td>
#       <td id="T_8ac86_row3_col5" class="data row3 col5" >25</td>
#     </tr>
#     <tr>
#       <th id="T_8ac86_level0_row4" class="row_heading level0 row4" >10</th>
#       <td id="T_8ac86_row4_col0" class="data row4 col0" >6,106</td>
#       <td id="T_8ac86_row4_col1" class="data row4 col1" >6,575</td>
#       <td id="T_8ac86_row4_col2" class="data row4 col2" >6,927</td>
#       <td id="T_8ac86_row4_col3" class="data row4 col3" >7,528</td>
#       <td id="T_8a

# %%
sns.heatmap(hour_dow, cmap='Purples', annot=True, fmt=',.0f')
# Out:
# <Axes: xlabel='InvoiceDayName', ylabel='InvoiceHour'>

# %%
hour_dow.plot()
# Out:
# <Axes: xlabel='InvoiceHour'>

# %%
plt.figure(figsize=(12,8))
hour_dow.plot(subplots=True, kind='area');

# %% [markdown]
# 3/7

# %%
arppu = df_valid.groupby(df_valid['InvoiceYM']).agg({'TotalPrice':'sum', 'CustomerID': 'nunique'})
arppu['ARPPU'] = arppu['TotalPrice'] / arppu['CustomerID']
arppu
# Out:
#             TotalPrice  CustomerID       ARPPU
# InvoiceYM
# 2010-12     570422.730         885  644.545458
# 2011-01     568101.310         741  766.668435
# 2011-02     446084.920         758  588.502533
# 2011-03     594081.760         974  609.940205
# 2011-04     468374.331         856  547.166275
# 2011-05     677355.150        1056  641.434801
# 2011-06     660046.050         991  666.040414
# 2011-07     598962.901         949  631.151634
# 2011-08     644051.040         935  688.824642
# 2011-09     950690.202        1266  750.940128
# 2011-10    1035642.450        1364  759.268658
# 2011-11    1156205.610        1664  694.835102
# 2011-12     517190.440         615  840.960065

# %%
# InvoiceYM 으로 그룹화 하여 CustomerID 의 유일값의 개수를 구합니다.
# MAU
cust_agg = df_valid.groupby(df_valid["CustomerID"]).agg({'InvoiceNo': 'count', 'TotalPrice':['mean', 'sum']})

# %%
cust_agg.describe()
# Out:
#          InvoiceNo    TotalPrice
#              count          mean            sum
# count  4338.000000   4338.000000    4338.000000
# mean     90.523744     68.381590    2048.688081
# std     225.506968   1467.918294    8985.230220
# min       1.000000      2.136970       3.750000
# 25%      17.000000     12.393196     306.482500
# 50%      41.000000     17.755000     668.570000
# 75%      98.000000     24.878950    1660.597500
# max    7676.000000  77183.600000  280206.020000

# %%
cust_agg.hist(bins=50)
# Out:
# array([[<Axes: title={'center': "('InvoiceNo', 'count')"}>,
#         <Axes: title={'center': "('TotalPrice', 'mean')"}>],
#        [<Axes: title={'center': "('TotalPrice', 'sum')"}>, <Axes: >]],
#       dtype=object)

# %%
MAU = df_valid.groupby('InvoiceYM').agg('CustomerID').nunique()
MAU.plot.bar(figsize=(10,3))
# Out:
# <Axes: xlabel='InvoiceYM'>

# %% [markdown]
# 월별, 주문건, 중복을 제외한 주문제품 종류

# %%
df_valid.head(3)
# Out:
#   InvoiceNo StockCode                         Description  Quantity  \
# 0    536365    85123A  WHITE HANGING HEART T-LIGHT HOLDER         6
# 1    536365     71053                 WHITE METAL LANTERN         6
# 2    536365    84406B      CREAM CUPID HEARTS COAT HANGER         8
#
#           InvoiceDate  UnitPrice  CustomerID         Country  TotalPrice  \
# 0 2010-12-01 08:26:00       2.55     17850.0  United Kingdom       15.30
# 1 2010-12-01 08:26:00       3.39     17850.0  United Kingdom       20.34
# 2 2010-12-01 08:26:00       2.75     17850.0  United Kingdom       22.00
#
#    isRegistered InvoiceCode  isCancel  InvoiceYear  InvoiceMonth  InvoiceDay  \
# 0          True                 False         2010            12           1
# 1          True                 False         2010            12           1
# 2          True                 False         2010            12           1
#
#    InvoiceDow InvoiceYM InvoiceTime  InvoiceHour InvoiceDayName
# 0           2   2010-12    08:26:00            8              수
# 1           2   2010-12    08:26:00            8              수
# 2           2   2010-12    08:26:00            8              수

# %%
# df_valid(유효고객, 유효주문)에 대해 월별 데이터(InvoiceYM)를 확인합니다.월별, 주문건, 중복을 제외한 주문제품 종류
# InvoiceNo 의 수
# StockCode, CustomerID 의 유일값의 수
# UnitPrice, Quantity, TotalPrice 의 sum
df_valid.groupby('InvoiceYM').agg({'InvoiceNo': 'count',
                                   'StockCode': 'nunique',
                                   'CustomerID': 'nunique',
                                   'UnitPrice': 'mean',
                                   'Quantity': 'sum',
                                   'TotalPrice': 'sum'})
# Out:
#            InvoiceNo  StockCode  CustomerID  UnitPrice  Quantity   TotalPrice
# InvoiceYM
# 2010-12        25670       2411         885   3.142953    311048   570422.730
# 2011-01        20988       2121         741   3.155834    348473   568101.310
# 2011-02        19706       2124         758   3.177686    265027   446084.920
# 2011-03        26870       2234         974   3.269996    347582   594081.760
# 2011-04        22433       2217         856   3.501247    291366   468374.331
# 2011-05        28073       2219        1056   3.615606    372864   677355.150
# 2011-06        26926       2339         991   3.142043    363014   660046.050
# 2011-07        26580       2351         949   2.838771    367360   598962.901
# 2011-08        26790       2356         935   2.944274    397373   644051.040
# 2011-09        39669       2545        1266   2.978656    543652   950690.202
# 2011-10        48793       2622        1364   3.362861    591543  1035642.450
# 2011-11        63168       2695        1664   2.886590    665923  1156205.610
# 2011-12        17026       2173         615   2.734624    286777   517190.440

# %% [markdown]
# [4/7]

# %%
df_valid.head(2
)
# Out:
#   InvoiceNo StockCode                         Description  Quantity  \
# 0    536365    85123A  WHITE HANGING HEART T-LIGHT HOLDER         6
# 1    536365     71053                 WHITE METAL LANTERN         6
#
#           InvoiceDate  UnitPrice  CustomerID         Country  TotalPrice  \
# 0 2010-12-01 08:26:00       2.55     17850.0  United Kingdom       15.30
# 1 2010-12-01 08:26:00       3.39     17850.0  United Kingdom       20.34
#
#    isRegistered InvoiceCode  isCancel  InvoiceYear  InvoiceMonth  InvoiceDay  \
# 0          True                 False         2010            12           1
# 1          True                 False         2010            12           1
#
#    InvoiceDow InvoiceYM InvoiceTime  InvoiceHour InvoiceDayName
# 0           2   2010-12    08:26:00            8              수
# 1           2   2010-12    08:26:00            8              수

# %%
# "최근 구매일 - 최초 구매일"로 첫 구매 후 몇달 후 구매인지를 알 수 있습니다.
# 최초 구매일( InvoiceDateFirst )을 구합니다.
# df_valid["InvoiceDateFirst"]

df_valid['InvoiceDateFirst'] = df_valid.groupby(['CustomerID'])['InvoiceDate'].transform('min')

# %%
df_valid[['CustomerID', 'InvoiceDate', 'InvoiceDateFirst']].sample(5)
# Out:
#         CustomerID         InvoiceDate    InvoiceDateFirst
# 491694     17759.0 2011-11-22 16:02:00 2011-06-23 13:35:00
# 425607     16923.0 2011-10-30 11:22:00 2010-12-12 11:06:00
# 227998     16523.0 2011-06-15 13:26:00 2011-01-28 12:06:00
# 425600     16923.0 2011-10-30 11:22:00 2010-12-12 11:06:00
# 501214     17562.0 2011-11-25 14:21:00 2011-06-19 13:06:00

# %%
year_diff = df_valid['InvoiceDate'].dt.year - df_valid['InvoiceDateFirst'].dt.year
month_diff = df_valid["InvoiceDate"].dt.month - df_valid["InvoiceDateFirst"].dt.month
month_diff.value_counts()
# Out:
#  0     124030
# -1      21677
#  2      18038
#  1      17405
#  3      15872
#  4      15537
#  5      14727
# -3      14098
# -2      13399
#  6      12393
#  7      11986
# -7      11946
#  8      11435
# -4      11316
# -5      11312
# -9      11121
# -6      11069
# -11     10111
# -8       9628
#  9       8870
# -10      8689
#  10      6699
#  11      1334
# Name: count, dtype: int64

# %%
df_valid.sample(2)
# Out:
#        InvoiceNo StockCode                   Description  Quantity  \
# 249810    558919     22993  SET OF 4 PANTRY JELLY MOULDS        12
# 95336     544453     22095          LADS ONLY TISSUE BOX         1
#
#                InvoiceDate  UnitPrice  CustomerID         Country  TotalPrice  \
# 249810 2011-07-05 09:56:00       1.25     15078.0  United Kingdom       15.00
# 95336  2011-02-20 13:06:00       1.25     17214.0  United Kingdom        1.25
#
#         isRegistered  ... isCancel  InvoiceYear  InvoiceMonth  InvoiceDay  \
# 249810          True  ...    False         2011             7           5
# 95336           True  ...    False         2011             2          20
#
#         InvoiceDow  InvoiceYM InvoiceTime InvoiceHour  InvoiceDayName  \
# 249810           1    2011-07    09:56:00           9               화
# 95336            6    2011-02    13:06:00          13               일
#
#           InvoiceDateFirst
# 249810 2010-12-06 12:38:00
# 95336  2010-12-15 15:14:00
#
# [2 rows x 21 columns]

# %%
df_valid['CohortIndex'] = (year_diff * 12) + month_diff + 1

# %%
df_valid['CohortIndex'].value_counts()
# Out:
# CohortIndex
# 1     116857
# 2      27516
# 4      26993
# 3      26727
# 6      26673
# 5      25165
# 7      23462
# 8      23298
# 12     23011
# 10     22968
# 9      22751
# 11     20098
# 13      7173
# Name: count, dtype: int64

# %%
plt.figure(figsize=(12,4))
sns.countplot(data=df_valid, x='CohortIndex')
# Out:
# <Axes: xlabel='CohortIndex', ylabel='count'>

# %%
df_valid['InvoiceDateFirstYM'] = df_valid['InvoiceDateFirst'].astype(str).str[:7]
df_valid["InvoiceDateFirstYM"].head()
# Out:
# 0    2010-12
# 1    2010-12
# 2    2010-12
# 3    2010-12
# 4    2010-12
# Name: InvoiceDateFirstYM, dtype: object

# %%
# InvoiceDateFirst, CohortIndex 로 그룹화 하여 CustomerID 의 유일값에 대한 빈도수를 구합니다.
# cohort_count
cohort_count = df_valid.groupby(['InvoiceDateFirstYM', 'CohortIndex'])['CustomerID'].nunique().unstack()
cohort_count
# Out:
# CohortIndex            1      2      3      4      5      6      7      8   \
# InvoiceDateFirstYM
# 2010-12             885.0  324.0  286.0  340.0  321.0  352.0  321.0  309.0
# 2011-01             417.0   92.0  111.0   96.0  134.0  120.0  103.0  101.0
# 2011-02             380.0   71.0   71.0  108.0  103.0   94.0   96.0  106.0
# 2011-03             452.0   68.0  114.0   90.0  101.0   76.0  121.0  104.0
# 2011-04             300.0   64.0   61.0   63.0   59.0   68.0   65.0   78.0
# 2011-05             284.0   54.0   49.0   49.0   59.0   66.0   75.0   27.0
# 2011-06             242.0   42.0   38.0   64.0   56.0   81.0   23.0    NaN
# 2011-07             188.0   34.0   39.0   42.0   51.0   21.0    NaN    NaN
# 2011-08             169.0   35.0   42.0   41.0   21.0    NaN    NaN    NaN
# 2011-09             299.0   70.0   90.0   34.0    NaN    NaN    NaN    NaN
# 2011-10             358.0   86.0   41.0    NaN    NaN    NaN    NaN    NaN
# 2011-11             323.0   36.0    NaN    NaN    NaN    NaN    NaN    NaN
# 2011-12              41.0    NaN    NaN    NaN    NaN    NaN    NaN    NaN
#
# CohortIndex            9      10     11     12     13
# InvoiceDateFirstYM
# 2010-12             313.0  350.0  331.0  445.0  235.0
# 2011-01             125.0  136.0  152.0   49.0    NaN
# 2011-02              94.0  116.0   26.0    NaN    NaN
# 2011-03             126.0   39.0    NaN    NaN    NaN
# 2011-04              22.0    NaN    NaN    NaN    NaN
# 2011-05               NaN    NaN    NaN    NaN    NaN
# 2011-06               NaN    NaN    NaN    NaN    NaN
# 2011-07               NaN    NaN    NaN    NaN    NaN
# 2011-08               NaN    NaN    NaN    NaN    NaN
# 2011-09               NaN    NaN    NaN    NaN    NaN
# 2011-10               NaN    NaN    NaN    NaN    NaN
# 2011-11               NaN    NaN    NaN    NaN    NaN
# 2011-12               NaN    NaN    NaN    NaN    NaN

# %%
plt.colormaps()
# Out:
# ['magma',
#  'inferno',
#  'plasma',
#  'viridis',
#  'cividis',
#  'twilight',
#  'twilight_shifted',
#  'turbo',
#  'berlin',
#  'managua',
#  'vanimo',
#  'Blues',
#  'BrBG',
#  'BuGn',
#  'BuPu',
#  'CMRmap',
#  'GnBu',
#  'Greens',
#  'Greys',
#  'OrRd',
#  'Oranges',
#  'PRGn',
#  'PiYG',
#  'PuBu',
#  'PuBuGn',
#  'PuOr',
#  'PuRd',
#  'Purples',
#  'RdBu',
#  'RdGy',
#  'RdPu',
#  'RdYlBu',
#  'RdYlGn',
#  'Reds',
#  'Spectral',
#  'Wistia',
#  'YlGn',
#  'YlGnBu',
#  'YlOrBr',
#  'YlOrRd',
#  'afmhot',
#  'autumn',
#  'binary',
#  'bone',
#  'brg',
#  'bwr',
#  'cool',
#  'coolwarm',
#  'copper',
#  'cubehelix',
#  'flag',
#  'gist_earth',
#  'gist_gray',
#  'gist_heat',
#  'gist_ncar',
#  'gist_rainbow',
#  'gist_stern',
#  'gist_yarg',
#  'gnuplot',
#  'gnuplot2',
#  'gray',
#  'hot',
#  'hsv',
#  'jet',
#  'nipy_spectral',
#  'ocean',
#  'pink',
#  'prism',
#  'rainbow',
#  'seismic',
#  'spring',
#  'summer',
#  'terrain',
#  'winter',
#  'Accent',
#  'Dark2',
#  'Paired',
#  'Pastel1',
#  'Pastel2',
#  'Set1',
#  'Set2',
#  'Set3',
#  'tab10',
#  'tab20',
#  'tab20b',
#  'tab20c',
#  'grey',
#  'gist_grey',
#  'gist_yerg',
#  'Grays',
#  'magma_r',
#  'inferno_r',
#  'plasma_r',
#  'viridis_r',
#  'cividis_r',
#  'twilight_r',
#  'twilight_shifted_r',
#  'turbo_r',
#  'berlin_r',
#  'managua_r',
#  'vanimo_r',
#  'Blues_r',
#  'BrBG_r',
#  'BuGn_r',
#  'BuPu_r',
#  'CMRmap_r',
#  'GnBu_r',
#  'Greens_r',
#  'Greys_r',
#  'OrRd_r',
#  'Oranges_r',
#  'PRGn_r',
#  'PiYG_r',
#  'PuBu_r',
#  'PuBuGn_r',
#  'PuOr_r',
#  'PuRd_r',
#  'Purples_r',
#  'RdBu_r',
#  'RdGy_r',
#  'RdPu_r',
#  'RdYlBu_r',
#  'RdYlGn_r',
#  'Reds_r',
#  'Spectral_r',
#  'Wistia_r',
#  'YlGn_r',
#  'YlGnBu_r',
#  'YlOrBr_r',
#  'YlOrRd_r',
#  'afmhot_r',
#  'autumn_r',
#  'binary_r',
#  'bone_r',
#  'brg_r',
#  'bwr_r',
#  'cool_r',
#  'coolwarm_r',
#  'copper_r',
#  'cubehelix_r',
#  'flag_r',
#  'gist_earth_r',
#  'gist_gray_r',
#  'gist_heat_r',
#  'gist_ncar_r',
#  'gist_rainbow_r',
#  'gist_stern_r',
#  'gist_yarg_r',
#  'gnuplot_r',
#  'gnuplot2_r',
#  'gray_r',
#  'hot_r',
#  'hsv_r',
#  'jet_r',
#  'nipy_spectral_r',
#  'ocean_r',
#  'pink_r',
#  'prism_r',
#  'rainbow_r',
#  'seismic_r',
#  'spring_r',
#  'summer_r',
#  'terrain_r',
#  'winter_r',
#  'Accent_r',
#  'Dark2_r',
#  'Paired_r',
#  'Pastel1_r',
#  'Pastel2_r',
#  'Set1_r',
#  'Set2_r',
#  'Set3_r',
#  'tab10_r',
#  'tab20_r',
#  'tab20b_r',
#  'tab20c_r',
#  'grey_r',
#  'gist_grey_r',
#  'gist_yerg_r',
#  'Grays_r',
#  'rocket',
#  'rocket_r',
#  'mako',
#  'mako_r',
#  'icefire',
#  'icefire_r',
#  'vlag',
#  'vlag_r',
#  'flare',
#  'flare_r',
#  'crest',
#  'crest_r']

# %%
plt.figure(figsize=(12,8))
sns.heatmap(cohort_count, cmap='Greens', annot=True, fmt='.0f')
# Out:
# <Axes: xlabel='CohortIndex', ylabel='InvoiceDateFirstYM'>

# %%
cohort_count[1]
# Out:
# InvoiceDateFirstYM
# 2010-12    885.0
# 2011-01    417.0
# 2011-02    380.0
# 2011-03    452.0
# 2011-04    300.0
# 2011-05    284.0
# 2011-06    242.0
# 2011-07    188.0
# 2011-08    169.0
# 2011-09    299.0
# 2011-10    358.0
# 2011-11    323.0
# 2011-12     41.0
# Name: 1, dtype: float64

# %%
plt.figure(figsize=(12, 4))
cohort_count[1].plot(rot=0, title='Monthly Acqusition')
# Out:
# <Axes: title={'center': 'Monthly Acqusition'}, xlabel='InvoiceDateFirstYM'>

# %%
plt.figure(figsize=(12,4))
cohort_count[1].plot(kind="bar", rot=0, title="Monthly Acqusition")
# Out:
# <Axes: title={'center': 'Monthly Acqusition'}, xlabel='InvoiceDateFirstYM'>

# %% [markdown]
# 잔존율 구하기

# %%
# 가입한 달을 1로 나누면 잔존률을 구할 수 있습니다.
# div 를 통해 구하며 axis=0 으로 설정하면 첫 달을 기준으로 나머지 달을 나누게 됩니다.
# cohort_norm

cohort_norm = cohort_count.div(cohort_count[1], axis=0)

# %%
plt.figure(figsize=(12,4))
sns.heatmap(cohort_norm, cmap='Oranges', annot=True)
# Out:
# <Axes: xlabel='CohortIndex', ylabel='InvoiceDateFirstYM'>

# %%
df_valid.head()
# Out:
#   InvoiceNo StockCode                          Description  Quantity  \
# 0    536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1    536365     71053                  WHITE METAL LANTERN         6
# 2    536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4    536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
#
#           InvoiceDate  UnitPrice  CustomerID         Country  TotalPrice  \
# 0 2010-12-01 08:26:00       2.55     17850.0  United Kingdom       15.30
# 1 2010-12-01 08:26:00       3.39     17850.0  United Kingdom       20.34
# 2 2010-12-01 08:26:00       2.75     17850.0  United Kingdom       22.00
# 3 2010-12-01 08:26:00       3.39     17850.0  United Kingdom       20.34
# 4 2010-12-01 08:26:00       3.39     17850.0  United Kingdom       20.34
#
#    isRegistered  ... InvoiceMonth  InvoiceDay  InvoiceDow  InvoiceYM  \
# 0          True  ...           12           1           2    2010-12
# 1          True  ...           12           1           2    2010-12
# 2          True  ...           12           1           2    2010-12
# 3          True  ...           12           1           2    2010-12
# 4          True  ...           12           1           2    2010-12
#
#    InvoiceTime  InvoiceHour InvoiceDayName    InvoiceDateFirst  CohortIndex  \
# 0     08:26:00            8              수 2010-12-01 08:26:00            1
# 1     08:26:00            8              수 2010-12-01 08:26:00            1
# 2     08:26:00            8              수 2010-12-01 08:26:00            1
# 3     08:26:00            8              수 2010-12-01 08:26:00            1
# 4     08:26:00            8              수 2010-12-01 08:26:00            1
#
#   InvoiceDateFirstYM
# 0            2010-12
# 1            2010-12
# 2            2010-12
# 3            2010-12
# 4            2010-12
#
# [5 rows x 23 columns]

# %%
cohort_total_price = df_valid.groupby(["InvoiceDateFirstYM", 'CohortIndex'])['TotalPrice'].sum().unstack()
cohort_total_price
# Out:
# CohortIndex                 1          2          3          4          5   \
# InvoiceDateFirstYM
# 2010-12             570422.730  275734.47  233390.47  302367.44  204034.38
# 2011-01             292366.840   54993.86   63157.01   71526.09   80989.77
# 2011-02             157700.590   28937.64   40964.47   48155.39   40089.17
# 2011-03             199619.670   30040.34   58958.41   42739.08   51392.44
# 2011-04             121809.051   29398.59   25028.57   24282.79   26253.16
# 2011-05             123739.300   18641.70   20155.73   19162.17   27752.62
# 2011-06             135414.800   14738.49   14104.37   30898.56   26669.90
# 2011-07              73860.401   11789.67   15488.37   17391.93   19156.82
# 2011-08              79601.140   20933.76   35458.48   44487.65   15284.36
# 2011-09             154734.091   28701.15   36898.95   12299.53        NaN
# 2011-10             173425.190   39691.40   12567.28        NaN        NaN
# 2011-11             135131.330   15223.34        NaN        NaN        NaN
# 2011-12              27005.460        NaN        NaN        NaN        NaN
#
# CohortIndex                6          7          8           9          10  \
# InvoiceDateFirstYM
# 2010-12             336113.69  313668.16  310304.03  331001.070  471792.13
# 2011-01              84464.57   70073.35   72503.42   71870.481  111370.70
# 2011-02              34155.67   49673.71   62292.80   55241.340   64688.86
# 2011-03              39962.33   64824.15   70523.62   70847.620   12761.10
# 2011-04              30103.24   28505.90   34009.61    6332.000        NaN
# 2011-05              32875.34   33168.34  179184.23         NaN        NaN
# 2011-06              42531.09    8143.22        NaN         NaN        NaN
# 2011-07               6040.70        NaN        NaN         NaN        NaN
# 2011-08                   NaN        NaN        NaN         NaN        NaN
# 2011-09                   NaN        NaN        NaN         NaN        NaN
# 2011-10                   NaN        NaN        NaN         NaN        NaN
# 2011-11                   NaN        NaN        NaN         NaN        NaN
# 2011-12                   NaN        NaN        NaN         NaN        NaN
#
# CohortIndex                11         12         13
# InvoiceDateFirstYM
# 2010-12             455478.90  512341.08  185360.97
# 2011-01             123252.86   26388.03        NaN
# 2011-02              10600.22        NaN        NaN
# 2011-03                   NaN        NaN        NaN
# 2011-04                   NaN        NaN        NaN
# 2011-05                   NaN        NaN        NaN
# 2011-06                   NaN        NaN        NaN
# 2011-07                   NaN        NaN        NaN
# 2011-08                   NaN        NaN        NaN
# 2011-09                   NaN        NaN        NaN
# 2011-10                   NaN        NaN        NaN
# 2011-11                   NaN        NaN        NaN
# 2011-12                   NaN        NaN        NaN

# %%
plt.figure(figsize=(20,4))
sns.heatmap(cohort_total_price, cmap='Blues', annot=True, fmt=',.0f')
# Out:
# <Axes: xlabel='CohortIndex', ylabel='InvoiceDateFirstYM'>
